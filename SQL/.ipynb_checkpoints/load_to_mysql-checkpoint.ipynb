# %% [markdown]
# # Healthcare Risk Platform

# %% [markdown]
# The purpose of this notebook is to load data into MySQL

# %%
from sqlalchemy import create_engine, URL
import pandas as pd

url = URL.create(
    drivername="mysql+pymysql",
    username="root",
    password="!TcmfDf9$5!_j@",
    host="localhost",
    port=3306,
    database="healthcare_risk_platform",
)

engine = create_engine(url)

# quick connection test before loading anything
with engine.connect() as conn:
    print("Connected!")

# %%
engine = create_engine(f"mysql+pymysql://root:{password}@localhost/healthcare_risk_platform")

patients_clean = pd.read_csv("../Data/Processed/patients_clean.csv")
admissions_clean = pd.read_csv("../Data/Processed/admissions_clean.csv")
diagnoses_clean = pd.read_csv("../Data/Processed/diagnoses_clean.csv")

patients_clean[["subject_id", "gender", "anchor_age", "deceased"]].to_sql(
    "patients", engine, if_exists="append", index=False)

admissions_clean[["hadm_id", "subject_id", "admittime", "dischtime", "admission_type",
                   "insurance", "race", "length_of_stay_days", "readmitted_30d"]].to_sql(
    "admissions", engine, if_exists="append", index=False)

diagnoses_clean[["hadm_id", "seq_num", "icd_code", "icd_version",
                  "is_primary_diagnosis", "diagnosis_label"]].to_sql(
    "diagnoses", engine, if_exists="append", index=False)

print("Loaded!")
